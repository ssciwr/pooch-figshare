# %% [markdown]
# # Demo of the pooch_figshare package

# %% [markdown]
# In the following we will demonstrate the pooch_figshare package. It is currently capable of doing impressive things:

# %%
import pooch_figshare

# %%
pooch_figshare.add_one(1)

# %% [markdown]
# There you go: `1+1=2`!
